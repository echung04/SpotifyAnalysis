# %% [markdown]
# # First Exploration of data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import requests
import os
from dotenv import load_dotenv

load_dotenv(".env")

client_id = os.getenv("SPOTIFY_CLIENT_ID")
client_secret = os.getenv("SPOTIFY_CLIENT_SECRET")

response = requests.post(
    "https://accounts.spotify.com/api/token",
    data={
        "grant_type": "client_credentials"
    },
    auth=(client_id, client_secret)
)



print(response.status_code)
print(response.text)
print("Client ID:", client_id)
print("Client Secret exists:", client_secret is not None)
# Out:
# 200
# {"access_token":"BQDfgvarn0mtXA-MFcykESf2fFjIPY4qHJg-8g8At_o5CuZYAX4E3-bUUC8gUgWCSmsm1pDt7LdXq4eiZUTJCO9la8-JFkDK4cAoOVFoP1rmcS_pBDPgV1jwxg61lXxkSCOvlO7Ip0xd","token_type":"Bearer","expires_in":3600}
# Client ID: 66a91fd613934f978eaa144f53c9ad22
# Client Secret exists: True

# %%
print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\Administrator\Documents\SPE 487\Spotify project\SpotifyAnalysis\Python
# ['.env', 'Python exploratoin.ipynb']
